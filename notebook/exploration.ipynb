# %% [markdown]
# # Camera Models Analysis
#
# EDA on a camera specification dataser

# %% [markdown]
# ## Importing libraries

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the dataset

# %%
df=pd.read_csv("D:\Camera Analysis\data\camera_dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# <>:1: SyntaxWarning: invalid escape sequence '\C'
# C:\Users\summi\AppData\Local\Temp\ipykernel_10468\2689940677.py:1: SyntaxWarning: invalid escape sequence '\C'
#   df=pd.read_csv("D:\Camera Analysis\data\camera_dataset.csv")

# %% [markdown]
# ## Analyzing the dataset

# %%
df.head()
# Out:
#                     Model  Release date  Max resolution  Low resolution  \
# 0        Agfa ePhoto 1280          1997          1024.0           640.0
# 1        Agfa ePhoto 1680          1998          1280.0           640.0
# 2        Agfa ePhoto CL18          2000           640.0             0.0
# 3        Agfa ePhoto CL30          1999          1152.0           640.0
# 4  Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
#
#    Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 0               0.0           38.0          114.0                70.0
# 1               1.0           38.0          114.0                50.0
# 2               0.0           45.0           45.0                 0.0
# 3               0.0           35.0           35.0                 0.0
# 4               0.0           43.0           43.0                50.0
#
#    Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1038 entries, 0 to 1037
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Model                    1038 non-null   object
#  1   Release date             1038 non-null   int64
#  2   Max resolution           1038 non-null   float64
#  3   Low resolution           1038 non-null   float64
#  4   Effective pixels         1038 non-null   float64
#  5   Zoom wide (W)            1038 non-null   float64
#  6   Zoom tele (T)            1038 non-null   float64
#  7   Normal focus range       1038 non-null   float64
#  8   Macro focus range        1037 non-null   float64
#  9   Storage included         1036 non-null   float64
#  10  Weight (inc. batteries)  1036 non-null   float64
#  11  Dimensions               1036 non-null   float64
#  12  Price                    1038 non-null   float64
# dtypes: float64(11), int64(1), object(1)
# ...

# %%
df.describe()
# Out:
#        Release date  Max resolution  Low resolution  Effective pixels  \
# count   1038.000000     1038.000000     1038.000000       1038.000000
# mean    2003.590559     2474.672447     1773.936416          4.596339
# std        2.724755      759.513608      830.897955          2.844044
# min     1994.000000        0.000000        0.000000          0.000000
# 25%     2002.000000     2048.000000     1120.000000          3.000000
# 50%     2004.000000     2560.000000     2048.000000          4.000000
# 75%     2006.000000     3072.000000     2560.000000          7.000000
# max     2007.000000     5616.000000     4992.000000         21.000000
#
#        Zoom wide (W)  Zoom tele (T)  Normal focus range  Macro focus range  \
# count    1038.000000    1038.000000         1038.000000        1037.000000
# mean       32.963391     121.525048           44.145472           7.787850
# std        10.333149      93.455422           24.141959           8.100081
# ...

# %%
df.shape
# Out:
# (1038, 13)

# %%
df.columns
# Out:
# Index(['Model', 'Release date', 'Max resolution', 'Low resolution',
#        'Effective pixels', 'Zoom wide (W)', 'Zoom tele (T)',
#        'Normal focus range', 'Macro focus range', 'Storage included',
#        'Weight (inc. batteries)', 'Dimensions', 'Price'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          1
# Storage included           2
# Weight (inc. batteries)    2
# Dimensions                 2
# Price                      0
# dtype: int64

# %%
df.dtypes
# Out:
# Model                       object
# Release date                 int64
# Max resolution             float64
# Low resolution             float64
# Effective pixels           float64
# Zoom wide (W)              float64
# Zoom tele (T)              float64
# Normal focus range         float64
# Macro focus range          float64
# Storage included           float64
# Weight (inc. batteries)    float64
# Dimensions                 float64
# Price                      float64
# dtype: object

# %% [markdown]
# ## Cleaning/Removing null values

# %%
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Model                      0
# Release date               0
# Max resolution             0
# Low resolution             0
# Effective pixels           0
# Zoom wide (W)              0
# Zoom tele (T)              0
# Normal focus range         0
# Macro focus range          0
# Storage included           0
# Weight (inc. batteries)    0
# Dimensions                 0
# Price                      0
# dtype: int64

# %%
df.shape
# Out:
# (1036, 13)

# %% [markdown]
# ## Stat analysis

# %%
prices= df["Price"]

# %%
avg_price = prices.mean()

# %%
avg_price
# Out:
# np.float64(457.9218146718147)

# %%
standard_deviation = prices.std()
standard_deviation
# Out:
# np.float64(761.0887349581401)

# %%
max_price = prices.max()
max_price
# Out:
# np.float64(7999.0)

# %%
min_price = prices.min()
min_price
# Out:
# np.float64(14.0)

# %%
variance = prices.var()
variance
# Out:
# np.float64(579256.062480182)

# %%
median_price = prices.median()

# %%
median_price
# Out:
# np.float64(199.0)

# %% [markdown]
# ## Some filtering

# %%
newest=df.loc[df["Release date"].idxmax()]
newest
# Out:
# Model                      Canon PowerShot A450
# Release date                               2007
# Max resolution                           2592.0
# Low resolution                           2048.0
# Effective pixels                            5.0
# Zoom wide (W)                              38.0
# Zoom tele (T)                             122.0
# Normal focus range                         47.0
# Macro focus range                           1.0
# Storage included                           16.0
# Weight (inc. batteries)                   215.0
# Dimensions                                106.0
# Price                                     139.0
# Name: 21, dtype: object

# %%
newest["Model"]
# Out:
# 'Canon PowerShot A450'

# %%
newest["Release date"]
# Out:
# np.int64(2007)

# %%
expensive=df.loc[df["Price"]>500]
expensive
# Out:
#                        Model  Release date  Max resolution  Low resolution  \
# 4     Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# 47             Canon EOS 10D          2003          3072.0          2048.0
# 48              Canon EOS-1D          2001          2464.0          1232.0
# 49      Canon EOS-1D Mark II          2004          3504.0          3104.0
# 50     Canon EOS-1D Mark III          2007          3888.0          3456.0
# ...                      ...           ...             ...             ...
# 1016       Sony Mavica FD-90          2000          1280.0          1280.0
# 1017       Sony Mavica FD-92          2001          1472.0          1280.0
# 1018       Sony Mavica FD-95          2000          1600.0          1600.0
# 1019       Sony Mavica FD-97          2001          1600.0          1024.0
# 1022        Toshiba PDR-4300          2003          2400.0          1200.0
#
# ...

# %%
expensive.head(3)
# Out:
#                      Model  Release date  Max resolution  Low resolution  \
# 4   Agfa ePhoto CL30 Clik!          1999          1152.0           640.0
# 47           Canon EOS 10D          2003          3072.0          2048.0
# 48            Canon EOS-1D          2001          2464.0          1232.0
#
#     Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 4                0.0           43.0           43.0                50.0
# 47               6.0            0.0            0.0                 0.0
# 48               4.0            0.0            0.0                 0.0
#
#     Macro focus range  Storage included  Weight (inc. batteries)  Dimensions  \
# 4                 0.0              40.0                    300.0       128.0
# 47                0.0               0.0                    875.0       150.0
# 48                0.0               0.0                   1585.0       156.0
#
#      Price
# 4   1299.0
# 47  1299.0
# 48  4499.0

# %%
len(expensive)
# Out:
# 163

# %%
high_resolution = df[df["Max resolution"] > 4000]
high_resolution.head()
# Out:
#                           Model  Release date  Max resolution  Low resolution  \
# 52                Canon EOS-1Ds          2002          4064.0          2032.0
# 53        Canon EOS-1Ds Mark II          2004          4992.0          3600.0
# 54       Canon EOS-1Ds Mark III          2007          5616.0          4992.0
# 62                 Canon EOS 5D          2005          4368.0          3168.0
# 241  Fujifilm FinePix E550 Zoom          2004          4048.0          2048.0
#
#      Effective pixels  Zoom wide (W)  Zoom tele (T)  Normal focus range  \
# 52               11.0            0.0            0.0                 0.0
# 53               16.0            0.0            0.0                 0.0
# 54               21.0            0.0            0.0                 0.0
# 62               12.0            0.0            0.0                 0.0
# 241               6.0           32.0          130.0                60.0
#
# ...

# %% [markdown]
# ## Visualization

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Price'], bins=30, color='blue', edgecolor='black')
plt.title('Price Distribution of Cameras')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['Max resolution'], df['Price'], color='red', alpha=0.5)
plt.title('Resolution vs Price of Cameras')
plt.xlabel('Max Resolution (MP)')
plt.ylabel('Price')
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Release year'] = df['Release date']
plt.hist(df['Release year'].dropna(), bins=30, color='green', edgecolor='black')
plt.title('Release Year Distribution of Cameras')
plt.xlabel('Release Year')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.figure(figsize=(10, 6))
df['Release year'] = df['Release date']
yearly_counts = df['Release year'].value_counts().sort_index()
plt.plot(yearly_counts.index, yearly_counts.values, marker='o', linestyle='-')
plt.title('Number of Cameras Released Each Year')
plt.xlabel('Year')
plt.ylabel('Number of Cameras')
plt.grid()
plt.show()

# %% [markdown]
# ## Correlation

# %%
df.corr(numeric_only=True)
# Out:
#                          Release date  Max resolution  Low resolution  \
# Release date                 1.000000        0.788234        0.750016
# Max resolution               0.788234        1.000000        0.842790
# Low resolution               0.750016        0.842790        1.000000
# Effective pixels             0.790263        0.953846        0.820322
# Zoom wide (W)               -0.071612       -0.373958       -0.206477
# Zoom tele (T)                0.193020        0.069377        0.154785
# Normal focus range          -0.074887       -0.200449       -0.125436
# Macro focus range           -0.253491       -0.347301       -0.315787
# Storage included             0.213093        0.166222        0.156652
# Weight (inc. batteries)     -0.259681        0.106678       -0.044927
# Dimensions                  -0.248877       -0.000057       -0.105585
# Price                       -0.022522        0.184201        0.154204
# ...

# %%
df[["Price", "Max resolution", "Weight (inc. batteries)"]].corr()
# Out:
#                             Price  Max resolution  Weight (inc. batteries)
# Price                    1.000000        0.184201                 0.464760
# Max resolution           0.184201        1.000000                 0.106678
# Weight (inc. batteries)  0.464760        0.106678                 1.000000
